# %%
class Coordinates:
    def __init__(self, x: float, y: float):
        self.x = x
        self.y = y

    def calculate_distance(self, point_from, point_to):
        pass

class GPS:
    def __init__(self, id: int, accuracy: float, have_signal: bool):
        self.id = id
        self.accuracy = accuracy
        self.have_signal = have_signal

    def get_current_coords(self):
        pass

class Driver:
    def __init__(self, id: int, name: str, surname: str, car=None, status: str = "", radio_number: int = 0):
        self.id = id
        self.name = name
        self.surname = surname
        self.car = car
        self.status = status
        self.radio_number = radio_number

    def start_shift(self, driver, car):
        pass

    def end_shift(self, driver):
        pass

    def to_repair(self, car):
        pass

    def from_repair(self, car):
        pass

class Operator:
    def __init__(self, id: int, name: str, surname: str):
        self.id = id
        self.name = name
        self.surname = surname

    def start_shift(self, driver, car):
        pass

    def end_shift(self, driver):
        pass

    def to_repair(self, car):
        pass

    def from_repair(self, car):
        pass

class Car:
    def __init__(self, id: int, class_type: str, model: str, firm: str, status: str, gps: GPS, driver: Driver, coords: Coordinates):
        self.id = id
        self.class_type = class_type
        self.model = model
        self.firm = firm
        self.status = status
        self.gps = gps
        self.driver = driver
        self.coords = coords

class Dump_Truck(Car):
    def __init__(self, id: int, class_type: str, model: str, firm: str, status: str, gps: GPS, driver: Driver, coords: Coordinates):
        super().__init__(id, class_type, model, firm, status, gps, driver, coords)

    def start_transportation(self, amount: float, material: str):
        pass

    def end_transportation(self):
        pass

class Mining_Dump_Truck(Car):
    def __init__(self, id: int, class_type: str, model: str, firm: str, status: str, gps: GPS, driver: Driver, coords: Coordinates, capacity: float = 0.0):
        super().__init__(id, class_type, model, firm, status, gps, driver, coords)
        self.capacity = capacity

    def start_transportation(self, amount: float):
        pass

    def end_transportation(self):
        pass

class Company_Car(Car):
    def __init__(self, id: int, class_type: str, model: str, firm: str, status: str, gps: GPS, driver: Driver, coords: Coordinates):
        super().__init__(id, class_type, model, firm, status, gps, driver, coords)

    def send_car(self, situation: str):
        pass

    def send_car_back(self):
        pass

class Quarry:
    def __init__(self, id: int, name: str, location: str):
        self.id = id
        self.name = name
        self.location = location
        self.car_list = []
        self.driver_list = []
        self.operator_list = []

    def add_car(self, car):
        self.car_list.append(car)

    def add_driver(self, driver):
        self.driver_list.append(driver)

    def add_operator(self, operator):
        self.operator_list.append(operator)
